# %% [markdown]
# # Linear Regression

# %%
#Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#plot everything within this notebook
# %matplotlib inline

# %%
#reading CSV
dataset = pd.read_csv('C:\\Users\\djha5\\Downloads\\DS_Meetup\\LinearRegression\\Linear_regression_dataset.csv')

# %%
#View the dataset
dataset.head()
# Out:
#    X_1  X_2  X_3    X_4    X_5  Output
# 0  734  688   81  0.328  0.259   0.418
# 1  700  600   94  0.320  0.247   0.389
# 2  712  705   93  0.311  0.247   0.417
# 3  734  806   69  0.315  0.260   0.415
# 4  613  759   61  0.302  0.240   0.378

# %%
#Shape of the data
print(dataset.shape)
# Out:
# (1232, 6)

# %%
#datatype of data
dataset.dtypes
# Out:
# X_1         int64
# X_2         int64
# X_3         int64
# X_4       float64
# X_5       float64
# Output    float64
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 6 columns):
# X_1       1232 non-null int64
# X_2       1232 non-null int64
# X_3       1232 non-null int64
# X_4       1232 non-null float64
# X_5       1232 non-null float64
# Output    1232 non-null float64
# dtypes: float64(3), int64(3)
# memory usage: 57.8 KB

# %%
#Description of Datset
dataset.Output.describe()
# Out:
# count    1232.000000
# mean        0.397342
# std         0.033267
# min         0.301000
# 25%         0.375000
# 50%         0.396000
# 75%         0.421000
# max         0.491000
# Name: Output, dtype: float64

# %%
#Visualize the targets
plt.hist(dataset.Output,bins=10,edgecolor='white')
plt.xlabel('Output')
plt.ylabel('frequency')
plt.title('Output Distribution')
plt.show()

# %%
dataset['X_3'].value_counts()[:5]
# Out:
# 83    49
# 86    46
# 79    43
# 76    43
# 88    43
# Name: X_3, dtype: int64

# %%
plt.scatter(dataset['X_1'],dataset['Output'])
plt.show()

# %%
plt.scatter(dataset['X_2'],dataset['Output'])
plt.show()

# %%
plt.scatter(dataset['X_3'],dataset['Output'])
plt.show()

# %%
plt.scatter(dataset['X_4'],dataset['Output'])
plt.show()

# %%
plt.scatter(dataset['X_5'],dataset['Output'])
plt.show()

# %%
import seaborn as sns
corr = dataset.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,cmap='BuGn')

# %%
pd.scatter_matrix(dataset, figsize=(6, 6))
plt.show()
# Out:
# C:\Users\starnn\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
x= dataset.iloc[:, :-1]
y= dataset.iloc[:, 5]

# %%
x.head()
# Out:
#    X_1  X_2  X_3    X_4    X_5
# 0  734  688   81  0.328  0.259
# 1  700  600   94  0.320  0.247
# 2  712  705   93  0.311  0.247
# 3  734  806   69  0.315  0.260
# 4  613  759   61  0.302  0.240

# %%
y.head()
# Out:
# 0    0.418
# 1    0.389
# 2    0.417
# 3    0.415
# 4    0.378
# Name: Output, dtype: float64

# %%
# Splitting the data in train and test
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state= 30)

# %%
# Shape of train and test dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (862, 4)
# (862,)
# (370, 4)
# (370,)

# %%
# Building the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
LR = regressor.fit(x_train,y_train)

# %%
y_predict = regressor.predict(x_test)

# %%
# Printing the result
print( " The results on Train set are : {:.5f}" .format(LR.score(x_train,y_train)))
print( " The results on Test set are : {:.5f}" .format(LR.score(x_test,y_test)))
# Out:
#  The results on Train set are : 0.85295
#  The results on Test set are : 0.86223

# %%
del x['X_4']

# %%
x.head()
# Out:
#    X_1  X_2  X_3    X_5
# 0  734  688   81  0.259
# 1  700  600   94  0.247
# 2  712  705   93  0.247
# 3  734  806   69  0.260
# 4  613  759   61  0.240

# %%
# Splitting the data in train and test
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state= 500)

# %%
# Shape of train and test dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (862, 4)
# (862,)
# (370, 4)
# (370,)

# %%
# Building the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
LR = regressor.fit(x_train,y_train)

# %%
y_predict = regressor.predict(x_test)

# %%
# Printing the result
print( " The results on Train set are : {:.5f}" .format(LR.score(x_train,y_train)))
print( " The results on Test set are : {:.5f}" .format(LR.score(x_test,y_test)))
# Out:
#  The results on Train set are : 0.85670
#  The results on Test set are : 0.85285
