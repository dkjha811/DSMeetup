# %% [markdown]
# # Linear Regression
#
# Important functions to keep in mind while fitting a linear regression model are:
#
# lm.fit() -> fits a linear model
#
# lm.predict() -> Predict Y using the linear model with estimated coefficients
#
# lm.score() -> Returns the coefficient of determination (R^2). A measure of how well observed outcomes are replicated by the model, as the proportion of total variation of outcomes explained by the model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#reading CSV data for Linear Regression
data = pd.read_csv('C:\\Users\\djha5\\Downloads\\DS_Meetup\\LinearRegression\\Linear_regression_dataset.csv')

# %%
data.head(2)
# Out:
#    X_1  X_2  X_3    X_4    X_5  Output
# 0  734  688   81  0.328  0.259   0.418
# 1  700  600   94  0.320  0.247   0.389

# %%
data.shape
# Out:
# (1232, 6)

# %%
#Visualize the targets
plt.hist(dataset.Output,bins=10,edgecolor='white')
plt.xlabel('Output')
plt.ylabel('frequency')
plt.title('Output Distribution')
plt.show()

# %%
plt.scatter(data['X_1'],data['Output'])
plt.xlabel('X_1')
plt.ylabel('Target column Output')
plt.title('Scatter Plot')
plt.show()

# %%
import seaborn as sns
corr = dataset.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,cmap='BuGn')

# %%
pd.scatter_matrix(dataset, figsize=(6, 6))
plt.show()
# Out:
# C:\Users\starnn\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
data.iloc[:, 5].head(2)
# Out:
# 0    0.418
# 1    0.389
# Name: Output, dtype: float64

# %%
data.iloc[:,:-1].head(2)
# Out:
#    X_1  X_2  X_3    X_4    X_5
# 0  734  688   81  0.328  0.259
# 1  700  600   94  0.320  0.247

# %%
y.head()
# Out:
# 0    0.418
# 1    0.389
# 2    0.417
# 3    0.415
# 4    0.378
# Name: Output, dtype: float64

# %%
# Splitting the data in train and test
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.iloc[:,:-1],data.iloc[:, 5], test_size = 0.40, random_state= 30)

# %%
# Shape of train and test dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (739, 5)
# (739L,)
# (493, 5)
# (493L,)

# %%
# Building the model
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(x_train,y_train)

# %%
# regression coefficients
print('Coefficients: \n', lr.coef_)
# Out:
# ('Coefficients: \n', array([  3.29199827e-04,   6.04264430e-05,   2.01186915e-04,
#         -6.24581756e-01,   4.67170623e-01]))

# %%
lr.residues_
# Out:
# C:\Users\djha5\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\utils\deprecation.py:70: DeprecationWarning: Function residues_ is deprecated; ``residues_`` is deprecated and will be removed in 0.19
#   warnings.warn(msg, category=DeprecationWarning)
# 0.10971622800335071

# %%
lr.score
# Out:
# <bound method LinearRegression.score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>

# %%
y_predict = lr.predict(x_test)

# %%
# Printing the result
print( " The results on Train set are : {:.5f}" .format(lr.score(x_train,y_train)))
print( " The results on Test set are : {:.5f}" .format(lr.score(x_test,y_test)))
# Out:
#  The results on Train set are : 0.86681
#  The results on Test set are : 0.87125

# %% [markdown]
# # Residual Plots
#
# Residual plots are a good way to visualize the errors in your data.  If you have done a good job then your data should be randomly scattered around line zero. If you see structure in your data, that means your model is not capturing some thing. Maye be there is a interaction between 2 variables that you are not considering, or may be you are measuring time dependent data. If you get some structure in your data, you should go back to your model and check whether you are doing a good job with your parameters.

# %%
plt.scatter(lr.predict(x_train),lr.predict(x_train)-y_train,c='b',s=40,alpha=0.5)
plt.scatter(lr.predict(x_test),lr.predict(x_test)-y_test,c='g',s=40)
plt.hlines(y=0,xmin=0,xmax=50)
plt.title("Residual Plot using training(blue) and test(green) data")
plt.ylabel("Residuals")

# %% [markdown]
# #    PRECISION AND RECALL
#
# Precision:
#
# Of those classified as Will return, what proportion actually did?
# True positive / (True positive + False positive)
# Recall:
#
# Recall: Of those that in fact Returned, what proportion were classified that way?
# True positive / (True positive + False negative)

# %%
#Idea to just call this method is to check , what error we get when we use confusion matrix in Linear regression
#Create Confusion Matrix for Evaluation
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-bf2dfb5d5a32> in <module>()
#       2 #Create Confusion Matrix for Evaluation
#       3 from sklearn.metrics import confusion_matrix
# ----> 4 cm = confusion_matrix(y_test, y_predict)
#
# C:\Users\djha5\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\metrics\classification.pyc in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     238
#     239     """
# --> 240     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     241     if y_type not in ("binary", "multiclass"):
#     242         raise ValueError("%s is not supported" % y_type)
#
# C:\Users\djha5\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\metrics\classification.pyc in _check_targets(y_true, y_pred)
#      87     # No metrics support "multiclass-multioutput" format
# ...
